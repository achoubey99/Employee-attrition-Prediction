# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt
# %matplotlib inline

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()   # no null entries
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df["Age"].head(5)
# Out:
# 0    41
# 1    49
# 2    37
# 3    33
# 4    27
# Name: Age, dtype: int64

# %%
df["JobRole"].head(5)
# Out:
# 0          Sales Executive
# 1       Research Scientist
# 2    Laboratory Technician
# 3       Research Scientist
# 4    Laboratory Technician
# Name: JobRole, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create the subplots
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# Violin plot for Gender and Age vs Attrition
sns.violinplot(x='Gender', y='Age', hue='Attrition', data=df, split=True, ax=ax[0])
ax[0].set_title('Gender and Age vs Attrition')

# Violin plot for RelationshipSatisfaction and Age vs Attrition
sns.violinplot(x='RelationshipSatisfaction', y='Age', hue='Attrition', data=df, split=True, ax=ax[1])
ax[1].set_title('RelationshipSatisfaction and Age vs Attrition')

# Show the plots
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# Violin plot for Gender and Age vs Attrition
sns.violinplot(x='Gender', y='Age', hue='Attrition', data=df, split=True, ax=ax[0])
ax[0].set_title('Gender and Age vs Attrition')

# Violin plot for RelationshipSatisfaction and Age vs Attrition
sns.violinplot(x='RelationshipSatisfaction', y='Age', hue='Attrition', data=df, split=True, ax=ax[1])
ax[1].set_title('RelationshipSatisfaction and Age vs Attrition')

# Show the plots
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x= 'Gender', y = 'Age',hue='Attrition',data=df,split=True,ax=ax[0])
ax[0].set_title('Gender and Age vs Attrition')

sns.violinplot(x = "Gender",y = "RelationshipSatisfaction", hue="Attrition", data=df,split=True,ax=ax[1])
ax[1].set_title('Gender and RelationshipSatisfaction vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x = 'Gender',y = 'Age',hue='Attrition',data=df,split=True,ax=ax[0])
ax[0].set_title('Gender and Age vs Attrition')

sns.countplot(x = "Gender", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('Gender  vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x='JobRole',hue='Attrition',data=df,ax=ax[0])
ax[0].set_title('JobRole vs Attrition')
ax[0].tick_params(axis='x', rotation=90)

sns.countplot(x= "JobLevel", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('JobLevel vs Attrition')


plt.show()

# %%
sns.countplot(x='JobRole',hue='Attrition',data=df)
plt.xticks(rotation = 90)

plt.show()

# %%
df["JobRole"].nunique()
# Out:
# 9

# %%
df["JobRole"].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df1 =df.copy()

# %%
df1["JobRole"].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df1["JobRole"] = df1["JobRole"].map({'Sales Executive':"S.E.",'Research Scientist':"R.S.",'Laboratory Technician':"L.T.",'Manufacturing Director':"M.D.",'Healthcare Representative' :"H.C.R",'Manager':'Manager','Sales Representative':"S.R.",'Research Director':"R.D.", 'Human Resources':"HR"})

# %%
sns.countplot(x= 'JobRole',hue='Attrition',data=df1)
# Out:
# <Axes: xlabel='JobRole', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x = 'JobRole',hue='Attrition',data=df1,ax=ax[0])
ax[0].set_title('JobRole vs Attrition')

sns.countplot(x = "JobLevel", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('JobLevel vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(18,10))
sns.countplot(x= 'JobRole',hue='Attrition',data=df1,ax=ax[0,0])
ax[0,0].set_title('JobRole vs Attrition')

sns.countplot(x = "JobLevel", hue="Attrition", data=df1,ax=ax[0,1])
ax[0,1].set_title('JobLevel vs Attrition')

sns.violinplot(x = 'JobLevel',y= 'MonthlyIncome',hue='Attrition',data=df1,split=True,ax=ax[1,0])
ax[1,0].set_title('JobLevel and MonthlyIncome vs Attrition')

sns.countplot(x = "OverTime", hue="Attrition", data=df1,ax=ax[1,1])
ax[1,1].set_title('OverTime vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(2,3,figsize=(20,10))
sns.countplot(x = 'JobRole',hue='Attrition',data=df1,ax=ax[0,0])
ax[0,0].set_title('JobRole vs Attrition')

sns.countplot(x = "JobLevel", hue="Attrition", data=df1,ax=ax[0,1])
ax[0,1].set_title('JobLevel vs Attrition')

sns.violinplot(x = 'JobLevel',y='MonthlyIncome',hue='Attrition',data=df1,split=True,ax=ax[0,2])
ax[0,2].set_title('JobLevel and MonthlyIncome vs Attrition')

sns.countplot(x = "OverTime", hue="Attrition", data=df1,ax=ax[1,0])
ax[1,0].set_title('OverTime vs Attrition')

sns.countplot(y = "TotalWorkingYears", hue="Attrition", data=df1,ax=ax[1,1])
ax[1,1].set_title('TotalWorkingYears vs Attrition')

sns.violinplot(x = 'JobRole',y= 'MonthlyIncome',hue='Attrition',data=df1,split=True,ax=ax[1,2])
ax[1,2].set_title('JobRole and MonthlyIncome vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(2,3,figsize=(20,10))
sns.countplot(x= 'JobRole',hue='Attrition',data=df1,ax=ax[0,0])
ax[0,0].set_title('JobRole vs Attrition')

sns.countplot(x = "JobLevel", hue="Attrition", data=df1,ax=ax[0,1])
ax[0,1].set_title('JobLevel vs Attrition')

sns.violinplot(x= 'JobLevel',y = 'MonthlyIncome',hue='Attrition',data=df1,split=True,ax=ax[0,2])
ax[0,2].set_title('JobLevel and MonthlyIncome vs Attrition')

sns.countplot(x = "OverTime", hue="Attrition", data=df1,ax=ax[1,0])
ax[1,0].set_title('OverTime vs Attrition')

sns.catplot(x="JobLevel" ,y ="TotalWorkingYears",col ="Gender" ,hue ="Attrition", data =df1,ax=ax[1,1])
ax[1,1].set_title('TotalWorkingYears vs Attrition')

sns.violinplot(x = 'JobRole',y= 'MonthlyIncome',hue='Attrition',data=df1,split=True,ax=ax[1,2])
ax[1,2].set_title('JobRole and MonthlyIncome vs Attrition')

plt.show()
# Out:
# C:\Users\achou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)
# C:\Users\achou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\achou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.catplot(x="JobLevel" ,y ="TotalWorkingYears",col ="OverTime" ,hue ="Attrition", kind ="bar", data =df1)

# %%
df1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
	
sns.histplot(df1[df1["Attrition"]== "Yes"].TotalWorkingYears, kde=False, label ="Yes")
sns.histplot(df1[df1["Attrition"]== "No"].TotalWorkingYears, kde=False, label ="No")
# Out:
# C:\Users\achou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\achou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TotalWorkingYears', ylabel='Count'>

# %%
df1["TotalWorkingYears"].nunique()
# Out:
# 40

# %%
df1.TotalWorkingYears.plot.hist(bins=5,edgecolor='black',color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x = 'OverTime',hue='Attrition',data=df1,ax=ax[0])
ax[0].set_title('OverTime vs Attrition')

sns.countplot(x = "YearsAtCompany", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('YearsAtCompany vs Attrition')

plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x= 'PercentSalaryHike',hue='Attrition',data=df1,ax=ax[0])
ax[0].set_title('PercentSalaryHike vs Attrition')

sns.countplot(x = "YearsAtCompany", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('YearsAtCompany vs Attrition')

plt.show()

# %%
df1[df1["PercentSalaryHike"] == 11]["PercentSalaryHike"].count()
# Out:
# 210

# %%
df1[df1["PercentSalaryHike"] == 11]["PercentSalaryHike"][""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df1[df1["PercentSalaryHike"] == 11]["PercentSalaryHike"][""]
#
# ...

# %%
df1[(df1["PercentSalaryHike"] == 11) & (df1["Attrition"] == "Yes")]["PercentSalaryHike"].count()
# Out:
# 41

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x='MaritalStatus',hue='Attrition',data=df1,ax=ax[0])
ax[0].set_title('MaritalStatus vs Attrition')

sns.countplot(x="WorkLifeBalance", hue="Attrition", data=df,ax=ax[1])
ax[1].set_title('WorkLifeBalance vs Attrition')

plt.show()

# %%
df1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...
